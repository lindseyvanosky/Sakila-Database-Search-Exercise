# %%
import pymysql
pymysql.install_as_MySQLdb()
import pandas as pd
import numpy as np

# %%
from sqlalchemy import create_engine

# %%
connection = "mysql+pymysql://root:Youknow1215@localhost/sakila"

# %%
engine = create_engine(connection)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/sakila)

# %% [markdown]
# ## Q1. What query would you run to get all the customers inside city_id = 312? Your query should return the customers' first name, last name, email, address, and city.

# %%
q = """SELECT 
    customer.first_name,
    customer.last_name,
    customer.email,
    customer.address_id,
    address.city_id
FROM
    customer
        JOIN
    address ON city_id
WHERE
    city_id = 312;"""

pd.read_sql(q, engine)
# Out:
#      first_name last_name                                email  address_id  \
# 0          MARY     SMITH        MARY.SMITH@sakilacustomer.org           5
# 1          MARY     SMITH        MARY.SMITH@sakilacustomer.org           5
# 2      PATRICIA   JOHNSON  PATRICIA.JOHNSON@sakilacustomer.org           6
# 3      PATRICIA   JOHNSON  PATRICIA.JOHNSON@sakilacustomer.org           6
# 4         LINDA  WILLIAMS    LINDA.WILLIAMS@sakilacustomer.org           7
# ...         ...       ...                                  ...         ...
# 1193    FREDDIE    DUGGAN    FREDDIE.DUGGAN@sakilacustomer.org         603
# 1194       WADE  DELVALLE     WADE.DELVALLE@sakilacustomer.org         604
# 1195       WADE  DELVALLE     WADE.DELVALLE@sakilacustomer.org         604
# 1196     AUSTIN   CINTRON    AUSTIN.CINTRON@sakilacustomer.org         605
# 1197     AUSTIN   CINTRON    AUSTIN.CINTRON@sakilacustomer.org         605
#
#       city_id
# 0         312
# 1         312
# 2         312
# ...

# %% [markdown]
# ## Q2. What query would you run to get all comedy films? Note that the genre is called the category in this schema.  Your query should return film title, description, release year, rating, and special features.

# %%
q = """SELECT 
    film.title,
    film.description,
    film.release_year,
    film.rating,
    film.special_features,
    film.film_id,
    category.name,
    film_category.film_id
FROM
    film
        JOIN
    film_category ON film_category.film_id = film.film_id
        JOIN
    category ON film_category.category_id = category.category_id
WHERE
    category.name = 'Comedy';"""

pd.read_sql(q, engine)
# Out:
#                       title  \
# 0           AIRPLANE SIERRA
# 1               ANTHEM LUKE
# 2       BRINGING HYSTERICAL
# 3             CAPER MOTIONS
# 4             CAT CONEHEADS
# 5               CLOSER BANG
# 6    CONNECTION MICROCOSMOS
# 7            CONTROL ANTHEM
# 8                CRAZY HOME
# 9          DADDY PITTSBURGH
# 10             DOOM DANCING
# 11          DOWNHILL ENOUGH
# 12              DYING MAKER
# 13           ELEMENT FREDDY
# 14            FERRIS MOTHER
# 15    FIREBALL PHILADELPHIA
# 16    FLINTSTONES HAPPINESS
# 17    FRANKENSTEIN STRANGER
# 18        FREEDOM CLEOPATRA
# 19               GOLD RIVER
# 20          GROUNDHOG UNCUT
# 21            GUNFIGHT MOON
# 22            HATE HANDICAP
# 23           HEAVEN FREEDOM
# 24             HEDWIG ALTER
# 25         HURRICANE AFFAIR
# 26            HUSTLER PARTY
# 27               JAWS HARRY
# 28            KNOCK WARLOCK
# 29             LIFE TWISTED
# 30               LION UNCUT
# 31          LONELY ELEPHANT
# ...

# %% [markdown]
# ## Q3. What query would you run to get all the films that Johnny Lollobrigida was in? Your query should return the actor's last name, film title, and release year.

# %%
q = """SELECT 
    actor.first_name,
    actor.last_name,
    film.title,
    film.release_year
FROM
    film_actor
        JOIN
    film ON film.film_id
        JOIN
    actor ON actor.actor_id
WHERE
    last_name = 'Lollobrigida'"""

pd.read_sql(q, engine)
# Out:
#         first_name     last_name              title  release_year
# 0           JOHNNY  LOLLOBRIGIDA          ZORRO ARK          2006
# 1           JOHNNY  LOLLOBRIGIDA  ZOOLANDER FICTION          2006
# 2           JOHNNY  LOLLOBRIGIDA       ZHIVAGO CORE          2006
# 3           JOHNNY  LOLLOBRIGIDA         YOUTH KICK          2006
# 4           JOHNNY  LOLLOBRIGIDA     YOUNG LANGUAGE          2006
# ...            ...           ...                ...           ...
# 5461995     JOHNNY  LOLLOBRIGIDA        AFRICAN EGG          2006
# 5461996     JOHNNY  LOLLOBRIGIDA   AFFAIR PREJUDICE          2006
# 5461997     JOHNNY  LOLLOBRIGIDA   ADAPTATION HOLES          2006
# 5461998     JOHNNY  LOLLOBRIGIDA     ACE GOLDFINGER          2006
# 5461999     JOHNNY  LOLLOBRIGIDA   ACADEMY DINOSAUR          2006
#
# [5462000 rows x 4 columns]

# %% [markdown]
# ## Q4. What query would you run to get the first and last names of all the actors in the movie titled "Bingo Talented"?

# %%
q = """SELECT 
    actor.first_name, actor.last_name
FROM
    actor
        JOIN
    film_actor ON film_actor.actor_id
        JOIN
    film ON film_actor.film_id
WHERE
    film.title = 'Bingo Talented';"""

pd.read_sql(q, engine)
# Out:
#         first_name     last_name
# 0            THORA        TEMPLE
# 1            JULIA       FAWCETT
# 2             MARY        KEITEL
# 3            REESE          WEST
# 4             BELA        WALKEN
# ...            ...           ...
# 1092395     JOHNNY  LOLLOBRIGIDA
# 1092396   JENNIFER         DAVIS
# 1092397         ED         CHASE
# 1092398       NICK      WAHLBERG
# 1092399   PENELOPE       GUINESS
#
# [1092400 rows x 2 columns]

# %% [markdown]
# ## 5. What query would you run to get the customer_id associated with all payments greater than twice the average payment amount? (HINT: use 2* in your query to get twice the amount). Your result should include the customer id and the amount.

# %%
q = """SELECT 
    payment.customer_id,
    payment.amount,
    AVG(payment.amount) AS AVG_AMOUNT
FROM
    payment
        JOIN
    customer ON customer.customer_id
GROUP BY payment.customer_id
HAVING payment.amount > 2 * AVG_AMOUNT
LIMIT 1;"""

pd.read_sql(q, engine)
# Out:
#    customer_id  amount  AVG_AMOUNT
# 0          598    7.99    3.808182

# %% [markdown]
# ## What query would you run to list the first and last names of the 5 customers who have the highest number(count) of payments? You can title the number of payments as num_payments.

# %%
q = """SELECT 
    customer.first_name,
    customer.last_name,
    payment.amount,
    COUNT(payment.amount) AS num_payments
FROM
    customer
        JOIN
    payment ON payment.customer_id
GROUP BY customer.first_name
ORDER BY num_payments DESC
LIMIT 5;"""

pd.read_sql(q, engine)
# Out:
#   first_name last_name  amount  num_payments
# 0      KELLY     KNOTT    2.99         32098
# 1     JESSIE     MILAM    2.99         32098
# 2     MARION    OCAMPO    2.99         32098
# 3      JAMIE     WAUGH    2.99         32098
# 4      TRACY  HERRMANN    2.99         32098
